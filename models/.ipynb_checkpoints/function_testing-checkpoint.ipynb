# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from datetime import datetime
import os.path
import time

import numpy as np
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

#from tensorflow.models.image.cifar10 import cifar10
import cifar10
import cifar10_mod

import sys
sys.path.append('/Users/xiejunyi/Dropbox/Research/MultiLevelOptNN/util')
sys.dont_write_bytecode = True

#from extract_weights import extract_weights
from Net2Net import Net2Net_class
from extract_weights import extract_weights
from train_load_net import train_load_net

# %%
FLAGS = tf.app.flags.FLAGS

tf.app.flags.DEFINE_string('train_dir', '/Users/xiejunyi/Dropbox/Research/MultiLevelOptNN/checkpoints/cifar10_train',
                           """Directory where to write event logs """
                           """and checkpoint.""")
tf.app.flags.DEFINE_string('train_dir_new', '/Users/xiejunyi/Dropbox/Research/MultiLevelOptNN/checkpoints/cifar10_train_new',
                           """Directory where to write event logs """
                           """and checkpoint.""")
tf.app.flags.DEFINE_integer('max_steps', 1000000,
                            """Number of batches to run.""")
tf.app.flags.DEFINE_boolean('log_device_placement', False,
                            """Whether to log device placement.""")

# %%
# download cifar10 dataset
cifar10.maybe_download_and_extract()

# %%
graph1 = tf.Graph()

with graph1.as_default():
  global_step = tf.Variable(0, trainable=False, name='global_step')

  # Get images and labels for CIFAR-10.
  images, labels = cifar10_mod.distorted_inputs()

  # Build a Graph that computes the logits predictions from the
  # inference model.
  logits = cifar10_mod.inference(images)

  # Calculate loss.
  loss = cifar10_mod.loss(logits, labels)

  # Build a Graph that trains the model with one batch of examples and
  # updates the model parameters.
  train_op = cifar10_mod.train(loss, global_step)
  
  # saver
  saver = tf.train.Saver(tf.all_variables())
  
  # summary
  summary_op = tf.merge_all_summaries()

  params = extract_weights(FLAGS.train_dir_new, saver)

with tf.Session(graph=graph1) as sess:
    a = sess.graph.get_operation_by_name('train').outputs
    b = sess.graph.get_operation_by_name('total_loss').outputs
    print(a)
    print(b)
# Out:
# Filling queue with 20000 CIFAR images before starting to train. This will take a few minutes.
# 1. Checkpoint path found.
#
# Load checkpoint state:
# model_checkpoint_path: "/Users/xiejunyi/Dropbox/Research/MultiLevelOptNN/checkpoints/cifar10_train_new/model.ckpt-0"
# all_model_checkpoint_paths: "/Users/xiejunyi/Dropbox/Research/MultiLevelOptNN/checkpoints/cifar10_train_new/model.ckpt-0"
#
# 2. Checkpoint restored.
#
# 3. Extracted weights info:
# global_step:0
# ()
# conv1/weights:0
# (5, 5, 3, 64)
# conv1/biases:0
# (64,)
# conv2/weights:0
# (5, 5, 64, 64)
# conv2/biases:0
# (64,)
# local3/weights:0
# (2304, 768)
# local3/biases:0
# (768,)
# local4/weights:0
# (768, 192)
# local4/biases:0
# (192,)
# softmax_linear/weights:0
# (192, 10)
# softmax_linear/biases:0
# (10,)
# conv1/weight_loss/avg:0
# ()
# conv2/weight_loss/avg:0
# ()
# local3/weight_loss/avg:0
# ()
# local4/weight_loss/avg:0
# ()
# softmax_linear/weight_loss/avg:0
# ()
# cross_entropy/avg:0
# ()
# total_loss/avg:0
# ()
# conv1/weights/ExponentialMovingAverage:0
# (5, 5, 3, 64)
# conv1/biases/ExponentialMovingAverage:0
# (64,)
# conv2/weights/ExponentialMovingAverage:0
# (5, 5, 64, 64)
# conv2/biases/ExponentialMovingAverage:0
# (64,)
# local3/weights/ExponentialMovingAverage:0
# (2304, 768)
# local3/biases/ExponentialMovingAverage:0
# (768,)
# local4/weights/ExponentialMovingAverage:0
# (768, 192)
# local4/biases/ExponentialMovingAverage:0
# (192,)
# softmax_linear/weights/ExponentialMovingAverage:0
# (192, 10)
# softmax_linear/biases/ExponentialMovingAverage:0
# (10,)
# []
# [<tf.Tensor 'total_loss:0' shape=() dtype=float32>]

# %%
if tf.gfile.Exists(FLAGS.train_dir):
  key_in = raw_input('Clear previously saved records? (y/n)\n')
  if (key_in == 'y'):
    print("Deleting records...\n")
    tf.gfile.DeleteRecursively(FLAGS.train_dir)
    tf.gfile.MakeDirs(FLAGS.train_dir)

  # extract weights
  key_in = raw_input('Train old or new network? (o/n)\n')
  if (key_in == 'o'):
    print('====================================================')
    print('Train old network')
    print('====================================================')
    train()
  elif (key_in == 'n'):
    print('====================================================')
    print('Train new network')
    print('====================================================')
    print('======================extract weights======================')
    
    print('======================train on new network======================')
    
    train_load_net(graph1, params, FLAGS.train_dir_new,
                   FLAGS.log_device_placement, FLAGS.max_steps, FLAGS.batch_size)
# Out:
# Clear previously saved records? (y/n)
# n
# Train old or new network? (o/n)
# n
# ====================================================
# Train new network
# ====================================================
# ======================extract weights======================
# ======================train on new network======================
# 0. train_load_net
# 1. restore all variables from params to current graph
# ----------
# global_step:0
# ()
# restored
# ----------
# conv1/weights:0
# (5, 5, 3, 64)
# restored
# ----------
# conv1/biases:0
# (64,)
# restored
# ----------
# conv2/weights:0
# (5, 5, 64, 64)
# restored
# ----------
# conv2/biases:0
# (64,)
# restored
# ----------
# local3/weights:0
# (2304, 768)
# restored
# ----------
# local3/biases:0
# (768,)
# restored
# ----------
# local4/weights:0
# (768, 192)
# restored
# ----------
# local4/biases:0
# (192,)
# restored
# ----------
# softmax_linear/weights:0
# (192, 10)
# restored
# ----------
# softmax_linear/biases:0
# (10,)
# restored
# ----------
# conv1/weight_loss/avg:0
# ()
# restored
# ----------
# conv2/weight_loss/avg:0
# ()
# restored
# ----------
# local3/weight_loss/avg:0
# ()
# restored
# ----------
# local4/weight_loss/avg:0
# ()
# restored
# ----------
# softmax_linear/weight_loss/avg:0
# ()
# restored
# ----------
# cross_entropy/avg:0
# ()
# restored
# ----------
# total_loss/avg:0
# ()
# restored
# ----------
# conv1/weights/ExponentialMovingAverage:0
# (5, 5, 3, 64)
# restored
# ----------
# conv1/biases/ExponentialMovingAverage:0
# (64,)
# restored
# ----------
# conv2/weights/ExponentialMovingAverage:0
# (5, 5, 64, 64)
# restored
# ----------
# conv2/biases/ExponentialMovingAverage:0
# (64,)
# restored
# ----------
# local3/weights/ExponentialMovingAverage:0
# (2304, 768)
# restored
# ----------
# local3/biases/ExponentialMovingAverage:0
# (768,)
# restored
# ----------
# local4/weights/ExponentialMovingAverage:0
# (768, 192)
# restored
# ----------
# local4/biases/ExponentialMovingAverage:0
# (192,)
# restored
# ----------
# softmax_linear/weights/ExponentialMovingAverage:0
# (192, 10)
# restored
# ----------
# softmax_linear/biases/ExponentialMovingAverage:0
# (10,)
# restored
# 2. start/resume training
# current step is 1
# 2016-11-14 16:02:49.522867: step 10, loss = 3.65 (251.6 examples/sec; 0.509 sec/batch)
# 2016-11-14 16:02:54.459218: step 20, loss = 3.60 (254.9 examples/sec; 0.502 sec/batch)
# 2016-11-14 16:02:59.444458: step 30, loss = 3.48 (254.7 examples/sec; 0.503 sec/batch)
# 2016-11-14 16:03:04.523785: step 40, loss = 3.43 (254.1 examples/sec; 0.504 sec/batch)
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: shuffle_batch/random_shuffle_queue_enqueue = QueueEnqueue[Tcomponents=[DT_FLOAT, DT_INT32], _class=["loc:@shuffle_batch/random_shuffle_queue"], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](shuffle_batch/random_shuffle_queue, Div, Cast)]]
#
# Caused by op u'shuffle_batch/random_shuffle_queue_enqueue', defined at:
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 653, in launch_instance
#     app.start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-1d4f06bdb1b0>", line 7, in <module>
#     images, labels = cifar10_mod.distorted_inputs()
#   File "cifar10_mod.py", line 157, in distorted_inputs
#     batch_size=FLAGS.batch_size)
#   File "cifar10_input.py", line 194, in distorted_inputs
#     shuffle=True)
#   File "cifar10_input.py", line 124, in _generate_image_and_label_batch
#     min_after_dequeue=min_queue_examples)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/input.py", line 805, in shuffle_batch
#     _enqueue(queue, tensor_list, num_threads, enqueue_many)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/input.py", line 494, in _enqueue
#     enqueue_ops = [queue.enqueue(tensor_list)] * threads
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/data_flow_ops.py", line 329, in enqueue
#     return gen_data_flow_ops._queue_enqueue(self._queue_ref, vals, name=scope)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/gen_data_flow_ops.py", line 982, in _queue_enqueue
#     name=name)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.py", line 756, in apply_op
#     op_def=op_def)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 2380, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 1298, in __init__
#     self._traceback = _extract_stack()
#
# CancelledError (see above for traceback): Enqueue operation was cancelled
# 	 [[Node: shuffle_batch/random_shuffle_queue_enqueue = QueueEnqueue[Tcomponents=[DT_FLOAT, DT_INT32], _class=["loc:@shuffle_batch/random_shuffle_queue"], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](shuffle_batch/random_shuffle_queue, Div, Cast)]]
#
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: shuffle_batch/random_shuffle_queue_enqueue = QueueEnqueue[Tcomponents=[DT_FLOAT, DT_INT32], _class=["loc:@shuffle_batch/random_shuffle_queue"], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](shuffle_batch/random_shuffle_queue, Div, Cast)]]
#
# Caused by op u'shuffle_batch/random_shuffle_queue_enqueue', defined at:
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 653, in launch_instance
#     app.start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-1d4f06bdb1b0>", line 7, in <module>
#     images, labels = cifar10_mod.distorted_inputs()
#   File "cifar10_mod.py", line 157, in distorted_inputs
#     batch_size=FLAGS.batch_size)
#   File "cifar10_input.py", line 194, in distorted_inputs
#     shuffle=True)
#   File "cifar10_input.py", line 124, in _generate_image_and_label_batch
#     min_after_dequeue=min_queue_examples)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/input.py", line 805, in shuffle_batch
#     _enqueue(queue, tensor_list, num_threads, enqueue_many)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/input.py", line 494, in _enqueue
#     enqueue_ops = [queue.enqueue(tensor_list)] * threads
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/data_flow_ops.py", line 329, in enqueue
#     return gen_data_flow_ops._queue_enqueue(self._queue_ref, vals, name=scope)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/gen_data_flow_ops.py", line 982, in _queue_enqueue
#     name=name)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.py", line 756, in apply_op
#     op_def=op_def)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 2380, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 1298, in __init__
#     self._traceback = _extract_stack()
#
# CancelledError (see above for traceback): Enqueue operation was cancelled
# 	 [[Node: shuffle_batch/random_shuffle_queue_enqueue = QueueEnqueue[Tcomponents=[DT_FLOAT, DT_INT32], _class=["loc:@shuffle_batch/random_shuffle_queue"], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](shuffle_batch/random_shuffle_queue, Div, Cast)]]
#
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: shuffle_batch/random_shuffle_queue_enqueue = QueueEnqueue[Tcomponents=[DT_FLOAT, DT_INT32], _class=["loc:@shuffle_batch/random_shuffle_queue"], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](shuffle_batch/random_shuffle_queue, Div, Cast)]]
#
# Caused by op u'shuffle_batch/random_shuffle_queue_enqueue', defined at:
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 653, in launch_instance
#     app.start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-1d4f06bdb1b0>", line 7, in <module>
#     images, labels = cifar10_mod.distorted_inputs()
#   File "cifar10_mod.py", line 157, in distorted_inputs
#     batch_size=FLAGS.batch_size)
#   File "cifar10_input.py", line 194, in distorted_inputs
#     shuffle=True)
#   File "cifar10_input.py", line 124, in _generate_image_and_label_batch
#     min_after_dequeue=min_queue_examples)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/input.py", line 805, in shuffle_batch
#     _enqueue(queue, tensor_list, num_threads, enqueue_many)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/input.py", line 494, in _enqueue
#     enqueue_ops = [queue.enqueue(tensor_list)] * threads
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/data_flow_ops.py", line 329, in enqueue
#     return gen_data_flow_ops._queue_enqueue(self._queue_ref, vals, name=scope)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/gen_data_flow_ops.py", line 982, in _queue_enqueue
#     name=name)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.py", line 756, in apply_op
#     op_def=op_def)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 2380, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 1298, in __init__
#     self._traceback = _extract_stack()
#
# CancelledError (see above for traceback): Enqueue operation was cancelled
# 	 [[Node: shuffle_batch/random_shuffle_queue_enqueue = QueueEnqueue[Tcomponents=[DT_FLOAT, DT_INT32], _class=["loc:@shuffle_batch/random_shuffle_queue"], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](shuffle_batch/random_shuffle_queue, Div, Cast)]]
#
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: shuffle_batch/random_shuffle_queue_enqueue = QueueEnqueue[Tcomponents=[DT_FLOAT, DT_INT32], _class=["loc:@shuffle_batch/random_shuffle_queue"], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](shuffle_batch/random_shuffle_queue, Div, Cast)]]
#
# Caused by op u'shuffle_batch/random_shuffle_queue_enqueue', defined at:
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 653, in launch_instance
#     app.start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-1d4f06bdb1b0>", line 7, in <module>
#     images, labels = cifar10_mod.distorted_inputs()
#   File "cifar10_mod.py", line 157, in distorted_inputs
#     batch_size=FLAGS.batch_size)
#   File "cifar10_input.py", line 194, in distorted_inputs
#     shuffle=True)
#   File "cifar10_input.py", line 124, in _generate_image_and_label_batch
#     min_after_dequeue=min_queue_examples)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/input.py", line 805, in shuffle_batch
#     _enqueue(queue, tensor_list, num_threads, enqueue_many)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/input.py", line 494, in _enqueue
#     enqueue_ops = [queue.enqueue(tensor_list)] * threads
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/data_flow_ops.py", line 329, in enqueue
#     return gen_data_flow_ops._queue_enqueue(self._queue_ref, vals, name=scope)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/gen_data_flow_ops.py", line 982, in _queue_enqueue
#     name=name)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.py", line 756, in apply_op
#     op_def=op_def)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 2380, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 1298, in __init__
#     self._traceback = _extract_stack()
#
# CancelledError (see above for traceback): Enqueue operation was cancelled
# 	 [[Node: shuffle_batch/random_shuffle_queue_enqueue = QueueEnqueue[Tcomponents=[DT_FLOAT, DT_INT32], _class=["loc:@shuffle_batch/random_shuffle_queue"], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](shuffle_batch/random_shuffle_queue, Div, Cast)]]
#
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: shuffle_batch/random_shuffle_queue_enqueue = QueueEnqueue[Tcomponents=[DT_FLOAT, DT_INT32], _class=["loc:@shuffle_batch/random_shuffle_queue"], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](shuffle_batch/random_shuffle_queue, Div, Cast)]]
#
# Caused by op u'shuffle_batch/random_shuffle_queue_enqueue', defined at:
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 653, in launch_instance
#     app.start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-1d4f06bdb1b0>", line 7, in <module>
#     images, labels = cifar10_mod.distorted_inputs()
#   File "cifar10_mod.py", line 157, in distorted_inputs
#     batch_size=FLAGS.batch_size)
#   File "cifar10_input.py", line 194, in distorted_inputs
#     shuffle=True)
#   File "cifar10_input.py", line 124, in _generate_image_and_label_batch
#     min_after_dequeue=min_queue_examples)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/input.py", line 805, in shuffle_batch
#     _enqueue(queue, tensor_list, num_threads, enqueue_many)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/input.py", line 494, in _enqueue
#     enqueue_ops = [queue.enqueue(tensor_list)] * threads
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/data_flow_ops.py", line 329, in enqueue
#     return gen_data_flow_ops._queue_enqueue(self._queue_ref, vals, name=scope)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/gen_data_flow_ops.py", line 982, in _queue_enqueue
#     name=name)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.py", line 756, in apply_op
#     op_def=op_def)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 2380, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 1298, in __init__
#     self._traceback = _extract_stack()
#
# CancelledError (see above for traceback): Enqueue operation was cancelled
# 	 [[Node: shuffle_batch/random_shuffle_queue_enqueue = QueueEnqueue[Tcomponents=[DT_FLOAT, DT_INT32], _class=["loc:@shuffle_batch/random_shuffle_queue"], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](shuffle_batch/random_shuffle_queue, Div, Cast)]]
#
# Exception in thread Thread-9:
# Traceback (most recent call last):
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/queue_runner.py", line 225, in _run
#     sess.run(enqueue_op)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 717, in run
#     run_metadata_ptr)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 915, in _run
#     feed_dict_string, options, run_metadata)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 965, in _do_run
#     target_list, options, run_metadata)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 985, in _do_call
#     raise type(e)(node_def, op, message)
# CancelledError: Enqueue operation was cancelled
# 	 [[Node: shuffle_batch/random_shuffle_queue_enqueue = QueueEnqueue[Tcomponents=[DT_FLOAT, DT_INT32], _class=["loc:@shuffle_batch/random_shuffle_queue"], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](shuffle_batch/random_shuffle_queue, Div, Cast)]]
#
# Caused by op u'shuffle_batch/random_shuffle_queue_enqueue', defined at:
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 653, in launch_instance
#     app.start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-1d4f06bdb1b0>", line 7, in <module>
#     images, labels = cifar10_mod.distorted_inputs()
#   File "cifar10_mod.py", line 157, in distorted_inputs
#     batch_size=FLAGS.batch_size)
#   File "cifar10_input.py", line 194, in distorted_inputs
#     shuffle=True)
#   File "cifar10_input.py", line 124, in _generate_image_and_label_batch
#     min_after_dequeue=min_queue_examples)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/input.py", line 805, in shuffle_batch
#     _enqueue(queue, tensor_list, num_threads, enqueue_many)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/input.py", line 494, in _enqueue
#     enqueue_ops = [queue.enqueue(tensor_list)] * threads
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/data_flow_ops.py", line 329, in enqueue
#     return gen_data_flow_ops._queue_enqueue(self._queue_ref, vals, name=scope)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/gen_data_flow_ops.py", line 982, in _queue_enqueue
#     name=name)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.py", line 756, in apply_op
#     op_def=op_def)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 2380, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 1298, in __init__
#     self._traceback = _extract_stack()
#
# CancelledError (see above for traceback): Enqueue operation was cancelled
# 	 [[Node: shuffle_batch/random_shuffle_queue_enqueue = QueueEnqueue[Tcomponents=[DT_FLOAT, DT_INT32], _class=["loc:@shuffle_batch/random_shuffle_queue"], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](shuffle_batch/random_shuffle_queue, Div, Cast)]]
#
#
# ERROR:tensorflow:Exception in QueueRunner: Enqueue operation was cancelled
# 	 [[Node: shuffle_batch/random_shuffle_queue_enqueue = QueueEnqueue[Tcomponents=[DT_FLOAT, DT_INT32], _class=["loc:@shuffle_batch/random_shuffle_queue"], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](shuffle_batch/random_shuffle_queue, Div, Cast)]]
#
# Caused by op u'shuffle_batch/random_shuffle_queue_enqueue', defined at:
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 653, in launch_instance
#     app.start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-1d4f06bdb1b0>", line 7, in <module>
#     images, labels = cifar10_mod.distorted_inputs()
#   File "cifar10_mod.py", line 157, in distorted_inputs
#     batch_size=FLAGS.batch_size)
#   File "cifar10_input.py", line 194, in distorted_inputs
#     shuffle=True)
#   File "cifar10_input.py", line 124, in _generate_image_and_label_batch
#     min_after_dequeue=min_queue_examples)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/input.py", line 805, in shuffle_batch
#     _enqueue(queue, tensor_list, num_threads, enqueue_many)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/input.py", line 494, in _enqueue
#     enqueue_ops = [queue.enqueue(tensor_list)] * threads
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/data_flow_ops.py", line 329, in enqueue
#     return gen_data_flow_ops._queue_enqueue(self._queue_ref, vals, name=scope)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/gen_data_flow_ops.py", line 982, in _queue_enqueue
#     name=name)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.py", line 756, in apply_op
#     op_def=op_def)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 2380, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 1298, in __init__
#     self._traceback = _extract_stack()
#
# CancelledError (see above for traceback): Enqueue operation was cancelled
# 	 [[Node: shuffle_batch/random_shuffle_queue_enqueue = QueueEnqueue[Tcomponents=[DT_FLOAT, DT_INT32], _class=["loc:@shuffle_batch/random_shuffle_queue"], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](shuffle_batch/random_shuffle_queue, Div, Cast)]]
#
# Exception in thread Thread-11:
# Traceback (most recent call last):
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/queue_runner.py", line 225, in _run
#     sess.run(enqueue_op)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 717, in run
#     run_metadata_ptr)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 915, in _run
#     feed_dict_string, options, run_metadata)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 965, in _do_run
#     target_list, options, run_metadata)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 985, in _do_call
#     raise type(e)(node_def, op, message)
# CancelledError: Enqueue operation was cancelled
# 	 [[Node: shuffle_batch/random_shuffle_queue_enqueue = QueueEnqueue[Tcomponents=[DT_FLOAT, DT_INT32], _class=["loc:@shuffle_batch/random_shuffle_queue"], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](shuffle_batch/random_shuffle_queue, Div, Cast)]]
#
# Caused by op u'shuffle_batch/random_shuffle_queue_enqueue', defined at:
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 653, in launch_instance
#     app.start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-1d4f06bdb1b0>", line 7, in <module>
#     images, labels = cifar10_mod.distorted_inputs()
#   File "cifar10_mod.py", line 157, in distorted_inputs
#     batch_size=FLAGS.batch_size)
#   File "cifar10_input.py", line 194, in distorted_inputs
#     shuffle=True)
#   File "cifar10_input.py", line 124, in _generate_image_and_label_batch
#     min_after_dequeue=min_queue_examples)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/input.py", line 805, in shuffle_batch
#     _enqueue(queue, tensor_list, num_threads, enqueue_many)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/input.py", line 494, in _enqueue
#     enqueue_ops = [queue.enqueue(tensor_list)] * threads
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/data_flow_ops.py", line 329, in enqueue
#     return gen_data_flow_ops._queue_enqueue(self._queue_ref, vals, name=scope)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/gen_data_flow_ops.py", line 982, in _queue_enqueue
#     name=name)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.py", line 756, in apply_op
#     op_def=op_def)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 2380, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 1298, in __init__
#     self._traceback = _extract_stack()
#
# CancelledError (see above for traceback): Enqueue operation was cancelled
# 	 [[Node: shuffle_batch/random_shuffle_queue_enqueue = QueueEnqueue[Tcomponents=[DT_FLOAT, DT_INT32], _class=["loc:@shuffle_batch/random_shuffle_queue"], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](shuffle_batch/random_shuffle_queue, Div, Cast)]]
#
#
# Exception in thread Thread-17:
# Traceback (most recent call last):
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/queue_runner.py", line 225, in _run
#     sess.run(enqueue_op)
# ...
#
#
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/queue_runner.py", line 225, in _run
#     sess.run(enqueue_op)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 717, in run
#     run_metadata_ptr)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 915, in _run
#     feed_dict_string, options, run_metadata)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 965, in _do_run
#     target_list, options, run_metadata)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 985, in _do_call
#     raise type(e)(node_def, op, message)
# CancelledError: Enqueue operation was cancelled
# 	 [[Node: shuffle_batch/random_shuffle_queue_enqueue = QueueEnqueue[Tcomponents=[DT_FLOAT, DT_INT32], _class=["loc:@shuffle_batch/random_shuffle_queue"], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](shuffle_batch/random_shuffle_queue, Div, Cast)]]
#
# Caused by op u'shuffle_batch/random_shuffle_queue_enqueue', defined at:
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 653, in launch_instance
#     app.start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-1d4f06bdb1b0>", line 7, in <module>
#     images, labels = cifar10_mod.distorted_inputs()
#   File "cifar10_mod.py", line 157, in distorted_inputs
#     batch_size=FLAGS.batch_size)
#   File "cifar10_input.py", line 194, in distorted_inputs
#     shuffle=True)
#   File "cifar10_input.py", line 124, in _generate_image_and_label_batch
#     min_after_dequeue=min_queue_examples)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/input.py", line 805, in shuffle_batch
#     _enqueue(queue, tensor_list, num_threads, enqueue_many)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/input.py", line 494, in _enqueue
#     enqueue_ops = [queue.enqueue(tensor_list)] * threads
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/data_flow_ops.py", line 329, in enqueue
#     return gen_data_flow_ops._queue_enqueue(self._queue_ref, vals, name=scope)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/gen_data_flow_ops.py", line 982, in _queue_enqueue
#     name=name)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.py", line 756, in apply_op
#     op_def=op_def)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 2380, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 1298, in __init__
#     self._traceback = _extract_stack()
#
# CancelledError (see above for traceback): Enqueue operation was cancelled
# 	 [[Node: shuffle_batch/random_shuffle_queue_enqueue = QueueEnqueue[Tcomponents=[DT_FLOAT, DT_INT32], _class=["loc:@shuffle_batch/random_shuffle_queue"], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](shuffle_batch/random_shuffle_queue, Div, Cast)]]
#
#
# Exception in thread Thread-14:
# Traceback (most recent call last):
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/queue_runner.py", line 225, in _run
#     sess.run(enqueue_op)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 717, in run
#     run_metadata_ptr)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 915, in _run
#     feed_dict_string, options, run_metadata)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 965, in _do_run
#     target_list, options, run_metadata)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.py", line 985, in _do_call
#     raise type(e)(node_def, op, message)
# CancelledError: Enqueue operation was cancelled
# 	 [[Node: shuffle_batch/random_shuffle_queue_enqueue = QueueEnqueue[Tcomponents=[DT_FLOAT, DT_INT32], _class=["loc:@shuffle_batch/random_shuffle_queue"], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](shuffle_batch/random_shuffle_queue, Div, Cast)]]
#
# Caused by op u'shuffle_batch/random_shuffle_queue_enqueue', defined at:
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 653, in launch_instance
#     app.start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-1d4f06bdb1b0>", line 7, in <module>
#     images, labels = cifar10_mod.distorted_inputs()
#   File "cifar10_mod.py", line 157, in distorted_inputs
#     batch_size=FLAGS.batch_size)
#   File "cifar10_input.py", line 194, in distorted_inputs
#     shuffle=True)
#   File "cifar10_input.py", line 124, in _generate_image_and_label_batch
#     min_after_dequeue=min_queue_examples)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/input.py", line 805, in shuffle_batch
#     _enqueue(queue, tensor_list, num_threads, enqueue_many)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/training/input.py", line 494, in _enqueue
#     enqueue_ops = [queue.enqueue(tensor_list)] * threads
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/data_flow_ops.py", line 329, in enqueue
#     return gen_data_flow_ops._queue_enqueue(self._queue_ref, vals, name=scope)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/gen_data_flow_ops.py", line 982, in _queue_enqueue
#     name=name)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.py", line 756, in apply_op
#     op_def=op_def)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 2380, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 1298, in __init__
#     self._traceback = _extract_stack()
#
# CancelledError (see above for traceback): Enqueue operation was cancelled
# 	 [[Node: shuffle_batch/random_shuffle_queue_enqueue = QueueEnqueue[Tcomponents=[DT_FLOAT, DT_INT32], _class=["loc:@shuffle_batch/random_shuffle_queue"], timeout_ms=-1, _device="/job:localhost/replica:0/task:0/cpu:0"](shuffle_batch/random_shuffle_queue, Div, Cast)]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-188578c279c0> in <module>()
#      24     #               FLAGS.log_device_placement, FLAGS.max_steps, FLAGS.batch_size)
#      25     train_load_net(graph1, params, FLAGS.train_dir_new,
# ---> 26                    FLAGS.log_device_placement, FLAGS.max_steps, FLAGS.batch_size)
#      27
#      28     #train_modified_net(params)
#
# /Users/xiejunyi/Dropbox/Research/MultiLevelOptNN/util/train_load_net.py in train_load_net(input_graph, params, train_dir, log_device_placement, max_steps, batch_size)
#      44           train_op = sess.graph.get_operation_by_name('train')
#      45           loss_op  = sess.graph.get_operation_by_name('total_loss').outputs[0]
# ---> 46           _ = sess.run(train_op)
#      47           loss_value = sess.run(loss_op)
#      48           #_, loss_value = sess.run([train_op, loss_op])
#
# /Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     715     try:
#     716       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 717                          run_metadata_ptr)
#     718       if run_metadata:
#     719         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     913     if final_fetches or final_targets:
#     914       results = self._do_run(handle, final_targets, final_fetches,
# --> 915                              feed_dict_string, options, run_metadata)
#     916     else:
#     917       results = []
#
# /Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     963     if handle is None:
#     964       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 965                            target_list, options, run_metadata)
#     966     else:
#     967       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#     970   def _do_call(self, fn, *args):
#     971     try:
# --> 972       return fn(*args)
#     973     except errors.OpError as e:
#     974       message = compat.as_text(e.message)
#
# /Users/xiejunyi/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     952         return tf_session.TF_Run(session, options,
#     953                                  feed_dict, fetch_list, target_list,
# --> 954                                  status, run_metadata)
#     955
#     956     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
